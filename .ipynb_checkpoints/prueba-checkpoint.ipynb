# %% [markdown]
# # Hola Cientificos

# %%
import random

# %%
def generar_matriz(N):
    matriz= []
    for i in range (N):
        fila = []
        for j in range(N):
            fila.append(random.randint(1, 9))
        matriz.append(fila)
    return matriz

N = 5

matriz_aleatoria = generar_matriz(N)
for fila in matriz_aleatoria:
    print(fila)

def imprimir_matriz(matriz):
    for fila in matriz:
        fila_formateada = ' '.join(f'{elemento:2}' for elemento in fila)
        print(fila_formateada)
# Out:
# [7, 6, 6, 8, 6]
# [2, 1, 8, 1, 3]
# [4, 5, 8, 1, 3]
# [7, 4, 5, 2, 4]
# [8, 1, 2, 3, 7]

# %%
print("Matriz de 5x5")
m_5 = generar_matriz(5)
imprimir_matriz(m_5)
print("============")
print("Matriz de 10x10")
m_10 = generar_matriz(10)
imprimir_matriz(m_10)
print("============")
print("Matriz de 20x20")
m_20 = generar_matriz(20)
imprimir_matriz(m_20)
# Out:
# Matriz de 5x5
#  1  4  5  7  4
#  2  2  6  9  2
#  3  8  6  4  7
#  4  4  1  5  1
#  4  3  9  5  9
# ============
# Matriz de 10x10
#  6  9  4  8  9  8  5  7  3  8
#  4  5  2  8  6  1  5  9  7  7
#  5  3  7  4  8  7  2  7  3  7
#  9  2  2  1  6  4  8  7  9  8
#  8  5  4  1  7  5  1  3  3  2
#  6  8  2  4  9  3  8  4  4  8
#  6  8  1  5  7  5  2  7  7  7
#  9  7  5  8  6  4  5  3  6  7
#  4  3  9  9  1  1  4  8  6  4
#  6  4  4  5  8  5  1  3  7  3
# ============
# Matriz de 20x20
#  6  5  6  3  1  3  6  1  9  4  9  8  4  3  4  8  6  2  4  3
#  4  7  2  3  4  7  2  6  5  3  6  2  5  7  6  9  4  4  9  4
#  1  2  3  9  8  7  6  5  4  3  2  2  2  9  8  9  3  4  7  4
#  1  1  5  6  3  1  9  3  3  2  3  8  3  9  1  3  6  5  4  5
#  5  3  2  3  9  1  2  1  9  3  9  7  4  7  2  7  9  4  1  9
#  3  1  9  8  3  7  5  4  7  9  8  9  1  8  6  2  9  4  5  7
#  2  1  3  4  2  6  9  5  5  8  7  2  5  6  5  5  8  4  3  4
#  5  4  8  6  8  8  7  6  6  2  9  5  6  9  8  9  4  7  3  4
#  2  1  3  3  2  8  1  1  4  9  1  9  8  9  7  4  3  5  7  1
#  2  3  9  3  9  6  1  5  4  8  3  6  5  8  9  1  9  4  6  7
#  8  2  3  2  1  5  6  9  7  5  4  5  8  9  7  9  3  9  3  1
#  1  3  3  9  5  4  3  3  5  5  9  9  8  5  7  5  8  6  7  1
#  6  9  9  3  9  9  2  4  7  3  1  3  4  4  6  6  8  4  2  9
#  5  1  1  2  1  6  4  5  9  8  3  8  4  7  9  4  5  5  1  8
#  8  6  7  3  9  4  9  3  4  4  5  1  7  8  9  5  9  1  4  6
#  3  3  3  4  3  4  9  1  9  9  5  3  5  3  9  4  1  3  3  1
#  2  8  6  4  5  7  5  4  5  9  1  8  5  7  1  8  7  7  3  2
#  5  1  6  8  1  4  9  4  2  6  4  1  9  9  9  3  8  2  9  3
#  8  2  4  8  6  3  9  3  2  4  5  5  6  4  7  7  6  7  9  4
#  6  4  2  6  1  9  9  8  8  6  6  5  5  8  3  6  4  6  9  2
